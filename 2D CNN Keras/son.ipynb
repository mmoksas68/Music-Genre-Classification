# %%
import os
import zipfile

# %% [markdown]
# # Data Preprocessing

# %%
test_data_path = '/content/gdrive/machine learning/mel_spec_data.zip/'
# train_data_path = 'drive/My Drive/ml2/train.zip'
local_zip = test_data_path
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('test')
zip_ref.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-61586262217e> in <module>()
#       2 # train_data_path = 'drive/My Drive/ml2/train.zip'
#       3 local_zip = test_data_path
# ----> 4 zip_ref = zipfile.ZipFile(local_zip, 'r')
#       5 zip_ref.extractall('test')
#       6 zip_ref.close()
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1111             while True:
#    1112                 try:
# -> 1113                     self.fp = io.open(file, filemode)
#    1114                 except OSError:
#    1115                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/machine learning/mel_spec_data.zip/'

# %%
import tensorflow as tf
from tensorflow.keras import regularizers

# %%
model = tf.keras.models.Sequential([

    tf.keras.layers.Conv2D(8, (5,5),activation='relu', input_shape=(400, 1000, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(8, (5,5),activation='relu'),

    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(16, (3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(32, (3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 396, 996, 8)       608
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 198, 498, 8)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 198, 498, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 194, 494, 8)       1608
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 97, 247, 8)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 97, 247, 8)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 95, 245, 16)       1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 47, 122, 16)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 120, 32)       4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 22, 60, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 42240)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              43254784
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 43,273,058
# Trainable params: 43,273,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
),
              metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255,validation_split = 0.40)
# test_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
        'test/mel_spec_data/', 
        target_size=(400, 1000),  
        batch_size=32,
        class_mode='categorical',
        subset="training")

validation_generator = train_datagen.flow_from_directory(
    'test/mel_spec_data/', # same directory as training data
    target_size=(400,1000),
    batch_size=32,
    class_mode='categorical',
    subset='validation') # set as validation data

# test_generator = test_datagen.flow_from_directory(
#     'test/test',
#     target_size=(120,120),
#     batch_size=128,
#     class_mode='categorical',  
# )
# Out:
# Found 600 images belonging to 10 classes.
# Found 400 images belonging to 10 classes.

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=8,  
      epochs=60,
      validation_data = validation_generator, 
      validation_steps = 8,
      verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-5-74ffd9a736de>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/60
# 8/8 [==============================] - 25s 3s/step - loss: 6.8042 - accuracy: 0.1172 - val_loss: 2.3035 - val_accuracy: 0.0977
# Epoch 2/60
# 8/8 [==============================] - 25s 3s/step - loss: 2.3387 - accuracy: 0.1094 - val_loss: 2.3020 - val_accuracy: 0.1042
# Epoch 3/60
# 8/8 [==============================] - 24s 3s/step - loss: 2.2946 - accuracy: 0.1331 - val_loss: 2.2994 - val_accuracy: 0.1125
# Epoch 4/60
# 8/8 [==============================] - 24s 3s/step - loss: 2.2868 - accuracy: 0.1055 - val_loss: 2.2864 - val_accuracy: 0.2070
# Epoch 5/60
# 8/8 [==============================] - 23s 3s/step - loss: 2.2250 - accuracy: 0.2177 - val_loss: 2.2166 - val_accuracy: 0.1750
# Epoch 6/60
# 8/8 [==============================] - 24s 3s/step - loss: 2.1020 - accuracy: 0.1992 - val_loss: 2.0772 - val_accuracy: 0.3542
# Epoch 7/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.9310 - accuracy: 0.2500 - val_loss: 2.0446 - val_accuracy: 0.2852
# Epoch 8/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.8710 - accuracy: 0.3347 - val_loss: 1.9735 - val_accuracy: 0.3458
# Epoch 9/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.8275 - accuracy: 0.2773 - val_loss: 1.8949 - val_accuracy: 0.4083
# Epoch 10/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.7756 - accuracy: 0.3629 - val_loss: 1.9257 - val_accuracy: 0.3164
# Epoch 11/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.7231 - accuracy: 0.3750 - val_loss: 1.8030 - val_accuracy: 0.3625
# Epoch 12/60
# 8/8 [==============================] - 23s 3s/step - loss: 1.5975 - accuracy: 0.4234 - val_loss: 1.7073 - val_accuracy: 0.3667
# Epoch 13/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.4210 - accuracy: 0.4961 - val_loss: 1.8249 - val_accuracy: 0.3750
# Epoch 14/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.4478 - accuracy: 0.4648 - val_loss: 1.7884 - val_accuracy: 0.4141
# Epoch 15/60
# 8/8 [==============================] - 23s 3s/step - loss: 1.3428 - accuracy: 0.5121 - val_loss: 1.5811 - val_accuracy: 0.4375
# Epoch 16/60
# 8/8 [==============================] - 23s 3s/step - loss: 1.2416 - accuracy: 0.5898 - val_loss: 1.7760 - val_accuracy: 0.3667
# Epoch 17/60
# 8/8 [==============================] - 24s 3s/step - loss: 1.0816 - accuracy: 0.6411 - val_loss: 1.6151 - val_accuracy: 0.4180
# Epoch 18/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.9251 - accuracy: 0.6680 - val_loss: 1.6680 - val_accuracy: 0.4167
# Epoch 19/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.8586 - accuracy: 0.7016 - val_loss: 1.7581 - val_accuracy: 0.4000
# Epoch 20/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.5754 - accuracy: 0.8125 - val_loss: 1.6521 - val_accuracy: 0.4492
# Epoch 21/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.6063 - accuracy: 0.8086 - val_loss: 1.8199 - val_accuracy: 0.4083
# Epoch 22/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.4536 - accuracy: 0.8871 - val_loss: 1.7218 - val_accuracy: 0.4458
# Epoch 23/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.3359 - accuracy: 0.9062 - val_loss: 1.8436 - val_accuracy: 0.4180
# Epoch 24/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.3119 - accuracy: 0.8952 - val_loss: 2.3095 - val_accuracy: 0.3542
# Epoch 25/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.2287 - accuracy: 0.9258 - val_loss: 1.8559 - val_accuracy: 0.4167
# Epoch 26/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.2564 - accuracy: 0.9102 - val_loss: 2.0592 - val_accuracy: 0.4219
# Epoch 27/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.2385 - accuracy: 0.9234 - val_loss: 1.8682 - val_accuracy: 0.4141
# Epoch 28/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.1885 - accuracy: 0.9336 - val_loss: 2.0562 - val_accuracy: 0.4208
# Epoch 29/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0798 - accuracy: 0.9839 - val_loss: 2.2186 - val_accuracy: 0.4125
# Epoch 30/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0938 - accuracy: 0.9648 - val_loss: 2.2652 - val_accuracy: 0.4023
# Epoch 31/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.1340 - accuracy: 0.9556 - val_loss: 2.2985 - val_accuracy: 0.4750
# Epoch 32/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.1133 - accuracy: 0.9648 - val_loss: 2.2302 - val_accuracy: 0.4458
# Epoch 33/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.1079 - accuracy: 0.9766 - val_loss: 2.3581 - val_accuracy: 0.3828
# Epoch 34/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0693 - accuracy: 0.9758 - val_loss: 2.3408 - val_accuracy: 0.4250
# Epoch 35/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0977 - accuracy: 0.9648 - val_loss: 2.6260 - val_accuracy: 0.4292
# Epoch 36/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0940 - accuracy: 0.9758 - val_loss: 2.3265 - val_accuracy: 0.4492
# Epoch 37/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0533 - accuracy: 0.9844 - val_loss: 1.9975 - val_accuracy: 0.4708
# Epoch 38/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0340 - accuracy: 0.9960 - val_loss: 2.3934 - val_accuracy: 0.3792
# Epoch 39/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0422 - accuracy: 0.9883 - val_loss: 2.2976 - val_accuracy: 0.4375
# Epoch 40/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0607 - accuracy: 0.9727 - val_loss: 2.7192 - val_accuracy: 0.4297
# Epoch 41/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0354 - accuracy: 0.9798 - val_loss: 2.5590 - val_accuracy: 0.4417
# Epoch 42/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0284 - accuracy: 0.9922 - val_loss: 2.5807 - val_accuracy: 0.4208
# Epoch 43/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0565 - accuracy: 0.9839 - val_loss: 3.0022 - val_accuracy: 0.3867
# Epoch 44/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0285 - accuracy: 0.9961 - val_loss: 2.6573 - val_accuracy: 0.4125
# Epoch 45/60
# 8/8 [==============================] - 23s 3s/step - loss: 0.0370 - accuracy: 0.9844 - val_loss: 2.7192 - val_accuracy: 0.4583
# Epoch 46/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0208 - accuracy: 0.9960 - val_loss: 3.5713 - val_accuracy: 0.3438
# Epoch 47/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0694 - accuracy: 0.9727 - val_loss: 2.9428 - val_accuracy: 0.3667
# Epoch 48/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0508 - accuracy: 0.9919 - val_loss: 2.7009 - val_accuracy: 0.4333
# Epoch 49/60
# 8/8 [==============================] - 25s 3s/step - loss: 0.0480 - accuracy: 0.9883 - val_loss: 2.6448 - val_accuracy: 0.4219
# Epoch 50/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0404 - accuracy: 0.9919 - val_loss: 2.9415 - val_accuracy: 0.3750
# Epoch 51/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0629 - accuracy: 0.9844 - val_loss: 2.5354 - val_accuracy: 0.4625
# Epoch 52/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0452 - accuracy: 0.9961 - val_loss: 2.5448 - val_accuracy: 0.4297
# Epoch 53/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0652 - accuracy: 0.9718 - val_loss: 2.6581 - val_accuracy: 0.4180
# Epoch 54/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0675 - accuracy: 0.9883 - val_loss: 3.0788 - val_accuracy: 0.3750
# Epoch 55/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0749 - accuracy: 0.9798 - val_loss: 2.4369 - val_accuracy: 0.4417
# Epoch 56/60
# 8/8 [==============================] - 25s 3s/step - loss: 0.0274 - accuracy: 0.9961 - val_loss: 2.8115 - val_accuracy: 0.3984
# Epoch 57/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0623 - accuracy: 0.9758 - val_loss: 2.8237 - val_accuracy: 0.4083
# Epoch 58/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0416 - accuracy: 0.9844 - val_loss: 2.7877 - val_accuracy: 0.3792
# Epoch 59/60
# 8/8 [==============================] - 25s 3s/step - loss: 0.0362 - accuracy: 0.9922 - val_loss: 2.5426 - val_accuracy: 0.4258
# Epoch 60/60
# 8/8 [==============================] - 24s 3s/step - loss: 0.0268 - accuracy: 0.9879 - val_loss: 3.1662 - val_accuracy: 0.4042
